# %% [markdown]
# <a href="https://colab.research.google.com/github/swathivenkatesan87/24ADI003-EXP1/blob/main/24bad122_EXP_1_SC2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Swathi 24BAD122")

import pandas as pd
import matplotlib.pyplot as plt



data = pd.read_csv("diabetes.csv")

print(data.head())
print(data.info())
print(data.describe())

outcome_count = data["Outcome"].value_counts()

print(outcome_count)

plt.figure(figsize=(6,4))
outcome_count.plot(kind='bar')
plt.title("Diabetic vs Non-Diabetic Patients")
plt.xlabel("Outcome (0 = Non-Diabetic, 1 = Diabetic)")
plt.ylabel("Count")
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()
# Out:
# Swathi 24BAD122
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
# ...
